# %%
# ===============================
# MASTER PIPELINE – EGYÉNI LSTM
# multi-input LSTM, mert különféle információforrásokat (idősorokat) kezel párhuzamosan, majd a végén összefűzi őket
# ===============================

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping


# ---------------------------------------------------
# 0) Segédfüggvények
# ---------------------------------------------------
def topk_acc_numpy(y_true, y_proba, k=5):
    # Ellenőrzi, hogy y_proba tényleg kétdimenziós-e
    if y_proba.ndim != 2:
        raise ValueError("y_proba 2D mátrix legyen (n_samples, n_classes).")
    
    # a lehetséges cellákra (vagyis célosztályokra) vonatkozó valószínűségek mátrixa -> oszlopainak száma = lehetséges osztályok száma
    n_classes = y_proba.shape[1]
    if n_classes == 0:
        return 0.0
    
    # megkeresi a k darab legvalószínűbb osztály indexét minden egyes mintára ->
    # majd ellenőrzi, hogy a valódi címke ezek között van-e ->
    # végül kiszámolja a helyes találatok arányát
    k_eff = min(k, n_classes)
    topk_idx = np.argpartition(y_proba, -k_eff, axis=1)[:, -k_eff:]
    correct = (topk_idx == y_true[:, None]).any(axis=1)
    return float(correct.mean())

def train_test_split_seq(X_list, y, split_ratio=0.8):
    # ez a függvény azért kell, mert több bemeneti típusú mátrixunk van (pl. cellák, félórák, numerikus jellemzők) -> a szokásos train_test_split() csak egy mátrixot tud kezelni
    # mivel midegyikben ugyanannyi sor van, ezért elég ugyanott elvágni őket
    n = len(y)  # szekvenciák száma
    split = int(n * split_ratio)  # kiszámolja, hány szekvencia kerül a tanító részbe, avagy a vágáspont indexét
    
    # az összes bemeneti mátrixot elvágja ugyanott
    X_train = [X[:split] for X in X_list]
    X_test  = [X[split:] for X in X_list]
    # az output mátrixot is elvágja
    y_train, y_test = y[:split], y[split:]

    return X_train, X_test, y_train, y_test

# ---------------------------------------------------
# 1) Előkészítés
# ---------------------------------------------------
def preprocess_dataframe(df, coarsen_factor=2):
    df = df.copy()

    # koordináták durvítása -> 200 cellából 100 cella -> majd cell_id képzése 
    # df["x_coarse"] = (df["x"] // coarsen_factor).astype(int)
    # df["y_coarse"] = (df["y"] // coarsen_factor).astype(int)
    # df["cell_id"] = df["x_coarse"] * 1000 + df["y_coarse"] # egyedi cellaazonosító képzése

    # időjellemzők képzése
    #df["hour"] = df["date"].dt.hour  ez hibás
    df["hour"] = df["t"].astype(int)
    # órák ciklikusságának kezelése sin és cos-sal
    df["hour_sin"] = np.sin(2 * np.pi * df["hour"] / 48)
    df["hour_cos"] = np.cos(2 * np.pi * df["hour"] / 48)
    df["is_weekend"] = (df["date"].dt.dayofweek >= 5).astype(int)

    # skálázandó numerikus jellemzők
    num_cols = ["temperature", "rain", "daily_radius_of_gyration",
                "radius_of_gyration", "unique_cells_count"]
    # hiányzó értékek 0-val való pótlása (kevés van ezért megengedett)
    for c in num_cols:
        if c not in df.columns:
            df[c] = 0.0

    # itt még ne skálázzuk, csak térjünk vissza az oszlopokkal (mert nem felhasználónként kell skálázni)
    df[num_cols] = df[num_cols].astype(float)

    # ha talál végtelen értéket, lecseréli NaN-ra, majd azokat 0-val pótolja
    df = df.replace([np.inf, -np.inf], np.nan).fillna(0)
    return df

# ---------------------------------------------------
# 2) Szekvenciák építése LSTM-hez
# ---------------------------------------------------
def build_sequences_for_user(user_df, seq_len=20):
    df = user_df.copy().reset_index(drop=True)

    # CELL_ID KÓDOLÁSA AZ LSTM-NEK MEGFELELŐ MÓDON
    # OUTPUT célérték képzése: a következő sor cell_id-ja
    df["target"] = df["cell_id"].shift(-1)
    df = df.dropna(subset=["target"]).reset_index(drop=True)  # az utolsó sor kiesik, mert nincs következő sor

    # cella_id (kategorikus) kódolása egész számokra (osztályokra) -> ne értelmezzen matematikai kapcsolatot a cell_id-k között
    # softmax miatt is kell (osztályokat jósol)
    # y_all: az összes célérték kódolt változata
    # uniques: az egyedi célértékek eredeti értékei (target-k)
    y_all, uniques = pd.factorize(df["target"].astype(int))
    df["target_enc"] = y_all.astype(np.int32)
    num_classes = len(uniques) # az egyedi osztályok száma (max 10)

    # ugyanaz mint feljebb, csak a bemeneti cell_id-kra
    cell_all, cell_uniques = pd.factorize(df["cell_id"].astype(int))
    df["cell_enc"] = cell_all.astype(np.int32)
    cell_vocab_size = int(df["cell_enc"].max()) + 2 # +2 az indexelés miatt és a padding miatt (ez megy az embedding réteg input_dim-jébe)

    df["dayofweek_enc"], _ = pd.factorize(df["days_of_week"])

    #hour_ids = df["hour"].astype(np.int32).values  # numpy tömbbé alakitása az órák értékeinek
    #num_feats = df[["hour_sin", "hour_cos", "is_weekend"]].astype(np.float32).values
    # MINDEN JELLEMZŐ BEVONÁSA
    hour_ids = df["hour"].astype(np.int32).values
    num_cols = [
        "temperature", "rain", "daily_radius_of_gyration",
        "radius_of_gyration", "unique_cells_count", "fraction_missing",
        "hour_sin", "hour_cos", "is_weekend",
        "is_home", "is_workplace",
        "dayofweek_enc"
    ]
    num_feats = df[num_cols].astype(np.float32).values

    # szekvenciák építése az adott user összes sorából
    X_cell, X_hour, X_num, y = [], [], [], []
    for i in range(len(df) - seq_len):
        sl = slice(i, i + seq_len)
        X_cell.append(df["cell_enc"].values[sl])
        X_hour.append(hour_ids[sl])
        X_num.append(num_feats[sl, :])
        y.append(df["target_enc"].values[i + seq_len - 1])

    # ha nincs elég adat szekvenciák képzéséhez, visszatér None-nal pl. ha 20-nál kevesebb rekord volt a userre 
    if len(y) == 0:
        return None

    # numpy tömbökké alakítás és megfelelő típusok beállítása az LSTM-hez
    return (np.asarray(X_cell, dtype=np.int32),
            np.asarray(X_hour, dtype=np.int32),
            np.asarray(X_num,  dtype=np.float32),
            np.asarray(y,      dtype=np.int32),
            cell_vocab_size, 48, num_classes)  # 48 mert 0-47 órák

# ---------------------------------------------------
# 3) Modell
# ---------------------------------------------------
def build_lstm_multi(num_cells, num_hours, num_numeric, num_classes):

    # cella-szekvencia bemenet - 1.tipus
    inp_cell = layers.Input(shape=(None,), dtype="int32", name="cell_in")
    # embedding réteg a cellaazonosítókhoz (64 dimenziós vektorok, mert nincs folytonos kapcsolat a cella id-k között, a modell maga tanulja meg a cellák közötti kapcsolatokat)
    # hasonlóan működik, mint a szavaknál a NLP-ben
    emb_cell = layers.Embedding(num_cells, 64, mask_zero=False)(inp_cell)
    x_cell = layers.LSTM(128, recurrent_dropout=0.1)(emb_cell)  # Ez az LSTM 128 neuronnal végigmegy a cellaembedding szekvencián és megtanulja, milyen sorrendek jellemzők a mozgásra -> 128 mintát tud párhuzamosan megfigyelni és megjegyezni

    # idő-szekvencia bemenet - 2.tipus
    inp_hour = layers.Input(shape=(None,), dtype="int32", name="hour_in")
    emb_hour = layers.Embedding(num_hours, 16, mask_zero=False)(inp_hour)
    x_hour = layers.LSTM(32)(emb_hour)  # megtanulja pl. éjszakai - nappali mozgásminták különbözőségét, rush-hour stb.

    # numerikus jellemzők szekvencia bemenet - 3.tipus (pl. eső, hőmérséklet, fraction_missing, is_home, is_workplace stb.)
    inp_num = layers.Input(shape=(None, num_numeric), dtype="float32", name="num_in")
    x_num = layers.LSTM(32)(inp_num)

    # összefűzi a 3 tipus kimeneteit: (batch_size, 128 + 32 + 32) = (batch_size, 192)
    x = layers.Concatenate()([x_cell, x_hour, x_num])
    # Egy rejtett réteg, amely a három forrásból származó információt kombinálja -> kb fele annyi neuronnal, mint az összefűzött bemenet, aktiváció ReLU -> nemlineáris kapcsolatokat is tud tanulni
    x = layers.Dense(128, activation="relu")(x)
    # kimeneti réteg softmax aktivációval -> célosztályok (célcellák) valószínűségei
    #x = layers.Dropout(0.2)(x)
    #x = layers.BatchNormalization()(x)  -> tulzottan lassította a tanulást
    out = layers.Dense(num_classes, activation="softmax")(x)

    # multi-LSTM modell összeállítása
    model = models.Model(inputs=[inp_cell, inp_hour, inp_num], outputs=out)
    # modell beállítások: Adam (Adaptive Moment Estimation) optimalizáló -> automatikusan állítja a tanulási rátát, gyorsan konvergál
    # sparse categorical crossentropy veszteségfüggvény -> mert a célértékek (y) egész számokként vannak kódolva és nem one-hot kódoltak
    # metrics: accuracy -> ez határozza meg, mit figyel a Keras a tanulás során és irja ki az epoch végén
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

def run_user_model_lstm_multi(df, uid, seq_len=20, epochs=20):
    
    # adott user adatainak kiválasztása (ha elég adat van róla)
    dfu = df[df["uid"] == uid].copy()
    if len(dfu) < 50:
        return None

    # kiválasztott user szekvenciáinak felépítése
    seqs = build_sequences_for_user(dfu, seq_len=seq_len)
    if seqs is None:
        return None
    X_cell, X_hour, X_num, y, cell_vocab, hour_vocab, num_classes = seqs

    # adatok felosztása tanító és teszt részre
    X_train, X_test, y_train, y_test = train_test_split_seq([X_cell, X_hour, X_num], y, split_ratio=0.8)

    # modell felépítése adott userre szabva
    model = build_lstm_multi(cell_vocab, hour_vocab, X_num.shape[2], num_classes) # X_num.shape[2] -> numerikus jellemzők száma időpillanatonként

    # korai leállítás beállítása -> ha 3 egymást követő epochban nem javul a validációs veszteség, akkor megállítja a tanulást és visszaállítja a legjobb súlyokat
    early_stop = EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)

    # modell tanítása
    history = model.fit(
                X_train, y_train,
                validation_split=0.1,
                epochs=epochs,
                batch_size=64,
                verbose=0,
                callbacks=[early_stop]
                )

    # --- Tanulási görbék vizualizálása ---

    # plt.figure(figsize=(8,5))
    # plt.plot(history.history["loss"], label="Train loss")
    # plt.plot(history.history["val_loss"], label="Validation loss")
    # plt.xlabel("Epoch")
    # plt.ylabel("Loss")
    # plt.legend()
    # plt.title(f"User {uid} - Loss görbe")
    # plt.show()

    # plt.figure(figsize=(8,4))
    # plt.plot(history.history["accuracy"], label="Train acc")
    # plt.plot(history.history["val_accuracy"], label="Val acc")
    # plt.xlabel("Epoch")
    # plt.ylabel("Pontosság")
    # plt.legend()
    # plt.title(f"User {uid} - Accuracy görbe")
    # plt.show() 

    # --- Kiértékelés külön a teszten ---
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"[{uid}] Test accuracy: {test_acc:.3f}, Test loss: {test_loss:.3f}")

    proba_test = model.predict(X_test, verbose=0)
    pred_test = np.argmax(proba_test, axis=1)
    acc = accuracy_score(y_test, pred_test)
    top5 = topk_acc_numpy(y_test, proba_test, k=5)

    return {
        "uid": uid,
        "model_type": "LSTM-multi", # modell típusa
        "num_classes": num_classes, # célosztályok száma
        "train_accuracy": history.history["accuracy"][-1],  # tanuló halmazon mért pontosság
        "val_accuracy": history.history["val_accuracy"][-1], # validációs halmazon mért pontosság
        "test_accuracy": test_acc,                     # teszt halmazon mért pontosság
        "accuracy": acc,                              #  pontosság (hány helyes predikció a teszten)
        "top5_accuracy": top5,                       # top-5 pontosság (hány esetben volt benne a helyes címke a 5 legvalószínűbb predikció között)
        "epochs_ran": len(history.history["loss"]),          # hány epoch futott le ténylegesen
        "final_train_loss": history.history["loss"][-1],     # utolsó tanító loss
        "final_val_loss": history.history["val_loss"][-1],   # utolsó validációs loss
        "best_val_loss": min(history.history["val_loss"]),   # legjobb validációs loss
        "best_epoch": np.argmin(history.history["val_loss"]) + 1,  # melyik epochban volt a legjobb
        "user_samples": len(dfu)  # hány sor volt az adott userhez az eredeti adatokban
    }


# ---------------------------------------------------
# 5) Futtatás checkpointtal
# ---------------------------------------------------
df = pd.read_csv("df_test_10k.csv", parse_dates=["date"])
df_processed = preprocess_dataframe(df)

# Globális skálázás a numerikus oszlopokra
num_cols = ["temperature", "rain", "daily_radius_of_gyration",
            "radius_of_gyration", "unique_cells_count"]

scaler = StandardScaler()
df_processed[num_cols] = scaler.fit_transform(df_processed[num_cols])

user_ids = sorted(df_processed["uid"].unique())

results_file = "results_checkpoint.csv"
checkpoint_file = "checkpoint.txt"

# ha van korábbi checkpoint, onnan folytatjuk
if os.path.exists(checkpoint_file):
    with open(checkpoint_file, "r") as f:
        start_index = int(f.read().strip())
else:
    start_index = 0

if os.path.exists(results_file):
    results_df = pd.read_csv(results_file)
    results = results_df.to_dict(orient="records")
else:
    results = []

for i, uid in enumerate(user_ids[start_index:], start=start_index):
    print(f"[{i+1}/{len(user_ids)}] User {uid} fut (LSTM multi-input)...")
    res = run_user_model_lstm_multi(df_processed, uid, seq_len=20, epochs=20)
    if res is not None:
        results.append(res)
        pd.DataFrame(results).to_csv(results_file, index=False)
    # checkpoint frissítése
    with open(checkpoint_file, "w") as f:
        f.write(str(i+1))

print("✅ Kész! Eredmények a fájlban:", results_file)
# Out:
# [9367/10000] User 9366 fut (LSTM multi-input)...
# [9366] Test accuracy: 0.378, Test loss: 3.389
# [9368/10000] User 9367 fut (LSTM multi-input)...
# [9367] Test accuracy: 0.118, Test loss: 3.279
# [9369/10000] User 9368 fut (LSTM multi-input)...
# [9368] Test accuracy: 0.316, Test loss: 3.877
# [9370/10000] User 9369 fut (LSTM multi-input)...
# [9369] Test accuracy: 0.333, Test loss: 2.431
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E70CC14CC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [9371/10000] User 9370 fut (LSTM multi-input)...
# [9370] Test accuracy: 0.551, Test loss: 2.068
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001E70CCC3380> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [9372/10000] User 9371 fut (LSTM multi-input)...
# [9371] Test accuracy: 0.184, Test loss: 4.980
# [9373/10000] User 9372 fut (LSTM multi-input)...
# [9372] Test accuracy: 0.400, Test loss: 2.579
# [9374/10000] User 9373 fut (LSTM multi-input)...
# [9373] Test accuracy: 0.142, Test loss: 4.463
# [9375/10000] User 9374 fut (LSTM multi-input)...
# [9374] Test accuracy: 0.276, Test loss: 2.013
# [9376/10000] User 9375 fut (LSTM multi-input)...
# [9375] Test accuracy: 0.358, Test loss: 3.350
# [9377/10000] User 9376 fut (LSTM multi-input)...
# [9376] Test accuracy: 0.157, Test loss: 3.716
# [9378/10000] User 9377 fut (LSTM multi-input)...
# [9377] Test accuracy: 0.140, Test loss: 5.128
# [9379/10000] User 9378 fut (LSTM multi-input)...
# [9378] Test accuracy: 0.285, Test loss: 3.857
# [9380/10000] User 9379 fut (LSTM multi-input)...
# [9379] Test accuracy: 0.316, Test loss: 2.443
# [9381/10000] User 9380 fut (LSTM multi-input)...
# [9380] Test accuracy: 0.129, Test loss: 5.392
# [9382/10000] User 9381 fut (LSTM multi-input)...
# [9381] Test accuracy: 0.308, Test loss: 2.634
# [9383/10000] User 9382 fut (LSTM multi-input)...
# [9382] Test accuracy: 0.151, Test loss: 4.496
# [9384/10000] User 9383 fut (LSTM multi-input)...
# [9383] Test accuracy: 0.154, Test loss: 5.062
# [9385/10000] User 9384 fut (LSTM multi-input)...
# [9384] Test accuracy: 0.329, Test loss: 2.417
# [9386/10000] User 9385 fut (LSTM multi-input)...
# [9385] Test accuracy: 0.274, Test loss: 4.107
# [9387/10000] User 9386 fut (LSTM multi-input)...
# [9386] Test accuracy: 0.083, Test loss: 4.066
# [9388/10000] User 9387 fut (LSTM multi-input)...
# [9387] Test accuracy: 0.048, Test loss: 5.128
# [9389/10000] User 9388 fut (LSTM multi-input)...
# [9388] Test accuracy: 0.096, Test loss: 5.569
# [9390/10000] User 9389 fut (LSTM multi-input)...
# [9389] Test accuracy: 0.393, Test loss: 2.639
# [9391/10000] User 9390 fut (LSTM multi-input)...
# [9390] Test accuracy: 0.177, Test loss: 4.355
# [9392/10000] User 9391 fut (LSTM multi-input)...
# [9391] Test accuracy: 0.197, Test loss: 4.503
# [9393/10000] User 9392 fut (LSTM multi-input)...
# [9392] Test accuracy: 0.039, Test loss: 5.970
# [9394/10000] User 9393 fut (LSTM multi-input)...
# [9393] Test accuracy: 0.417, Test loss: 2.784
# [9395/10000] User 9394 fut (LSTM multi-input)...
# [9394] Test accuracy: 0.104, Test loss: 5.470
# [9396/10000] User 9395 fut (LSTM multi-input)...
# [9395] Test accuracy: 0.189, Test loss: 3.284
# [9397/10000] User 9396 fut (LSTM multi-input)...
# [9396] Test accuracy: 0.107, Test loss: 4.275
# [9398/10000] User 9397 fut (LSTM multi-input)...
# [9397] Test accuracy: 0.311, Test loss: 2.610
# [9399/10000] User 9398 fut (LSTM multi-input)...
# [9398] Test accuracy: 0.524, Test loss: 1.996
# [9400/10000] User 9399 fut (LSTM multi-input)...
# [9399] Test accuracy: 0.371, Test loss: 2.540
# [9401/10000] User 9400 fut (LSTM multi-input)...
# [9400] Test accuracy: 0.362, Test loss: 3.109
# [9402/10000] User 9401 fut (LSTM multi-input)...
# [9401] Test accuracy: 0.105, Test loss: 5.412
# [9403/10000] User 9402 fut (LSTM multi-input)...
# [9402] Test accuracy: 0.413, Test loss: 2.585
# [9404/10000] User 9403 fut (LSTM multi-input)...
# [9403] Test accuracy: 0.157, Test loss: 3.881
# [9405/10000] User 9404 fut (LSTM multi-input)...
# [9404] Test accuracy: 0.199, Test loss: 4.263
# [9406/10000] User 9405 fut (LSTM multi-input)...
# [9405] Test accuracy: 0.355, Test loss: 3.649
# [9407/10000] User 9406 fut (LSTM multi-input)...
# [9406] Test accuracy: 0.606, Test loss: 1.586
# [9408/10000] User 9407 fut (LSTM multi-input)...
# [9407] Test accuracy: 0.230, Test loss: 3.801
# [9409/10000] User 9408 fut (LSTM multi-input)...
# [9408] Test accuracy: 0.082, Test loss: 5.402
# [9410/10000] User 9409 fut (LSTM multi-input)...
# [9409] Test accuracy: 0.122, Test loss: 5.575
# [9411/10000] User 9410 fut (LSTM multi-input)...
# [9410] Test accuracy: 0.265, Test loss: 4.200
# [9412/10000] User 9411 fut (LSTM multi-input)...
# [9411] Test accuracy: 0.209, Test loss: 4.605
# [9413/10000] User 9412 fut (LSTM multi-input)...
# [9412] Test accuracy: 0.044, Test loss: 5.424
# [9414/10000] User 9413 fut (LSTM multi-input)...
# [9413] Test accuracy: 0.478, Test loss: 2.474
# [9415/10000] User 9414 fut (LSTM multi-input)...
# [9414] Test accuracy: 0.361, Test loss: 2.452
# [9416/10000] User 9415 fut (LSTM multi-input)...
# [9415] Test accuracy: 0.088, Test loss: 5.508
# [9417/10000] User 9416 fut (LSTM multi-input)...
# [9416] Test accuracy: 0.114, Test loss: 5.078
# [9418/10000] User 9417 fut (LSTM multi-input)...
# [9417] Test accuracy: 0.335, Test loss: 2.614
# [9419/10000] User 9418 fut (LSTM multi-input)...
# [9418] Test accuracy: 0.474, Test loss: 2.458
# [9420/10000] User 9419 fut (LSTM multi-input)...
# [9419] Test accuracy: 0.088, Test loss: 5.489
# [9421/10000] User 9420 fut (LSTM multi-input)...
# [9420] Test accuracy: 0.120, Test loss: 5.362
# [9422/10000] User 9421 fut (LSTM multi-input)...
# [9421] Test accuracy: 0.090, Test loss: 4.789
# [9423/10000] User 9422 fut (LSTM multi-input)...
# [9422] Test accuracy: 0.121, Test loss: 4.946
# [9424/10000] User 9423 fut (LSTM multi-input)...
# [9423] Test accuracy: 0.013, Test loss: 5.734
# [9425/10000] User 9424 fut (LSTM multi-input)...
# [9424] Test accuracy: 0.373, Test loss: 1.995
# [9426/10000] User 9425 fut (LSTM multi-input)...
# [9425] Test accuracy: 0.182, Test loss: 4.670
# [9427/10000] User 9426 fut (LSTM multi-input)...
# [9426] Test accuracy: 0.290, Test loss: 3.612
# [9428/10000] User 9427 fut (LSTM multi-input)...
# [9427] Test accuracy: 0.061, Test loss: 6.118
# [9429/10000] User 9428 fut (LSTM multi-input)...
# [9428] Test accuracy: 0.300, Test loss: 3.650
# [9430/10000] User 9429 fut (LSTM multi-input)...
# [9429] Test accuracy: 0.067, Test loss: 5.286
# [9431/10000] User 9430 fut (LSTM multi-input)...
# [9430] Test accuracy: 0.267, Test loss: 3.148
# [9432/10000] User 9431 fut (LSTM multi-input)...
# [9431] Test accuracy: 0.118, Test loss: 5.507
# [9433/10000] User 9432 fut (LSTM multi-input)...
# [9432] Test accuracy: 0.095, Test loss: 5.195
# [9434/10000] User 9433 fut (LSTM multi-input)...
# [9433] Test accuracy: 0.212, Test loss: 4.381
# [9435/10000] User 9434 fut (LSTM multi-input)...
# [9434] Test accuracy: 0.066, Test loss: 5.005
# [9436/10000] User 9435 fut (LSTM multi-input)...
# [9435] Test accuracy: 0.411, Test loss: 2.340
# [9437/10000] User 9436 fut (LSTM multi-input)...
# [9436] Test accuracy: 0.425, Test loss: 3.285
# [9438/10000] User 9437 fut (LSTM multi-input)...
# [9437] Test accuracy: 0.238, Test loss: 4.460
# [9439/10000] User 9438 fut (LSTM multi-input)...
# [9438] Test accuracy: 0.051, Test loss: 6.129
# [9440/10000] User 9439 fut (LSTM multi-input)...
# [9439] Test accuracy: 0.490, Test loss: 2.846
# [9441/10000] User 9440 fut (LSTM multi-input)...
# [9440] Test accuracy: 0.273, Test loss: 3.427
# [9442/10000] User 9441 fut (LSTM multi-input)...
# [9441] Test accuracy: 0.056, Test loss: 6.134
# [9443/10000] User 9442 fut (LSTM multi-input)...
# [9442] Test accuracy: 0.277, Test loss: 4.168
# [9444/10000] User 9443 fut (LSTM multi-input)...
# [9443] Test accuracy: 0.280, Test loss: 3.965
# [9445/10000] User 9444 fut (LSTM multi-input)...
# [9444] Test accuracy: 0.032, Test loss: 5.875
# [9446/10000] User 9445 fut (LSTM multi-input)...
# [9445] Test accuracy: 0.189, Test loss: 3.825
# [9447/10000] User 9446 fut (LSTM multi-input)...
# [9446] Test accuracy: 0.785, Test loss: 1.398
# [9448/10000] User 9447 fut (LSTM multi-input)...
# [9447] Test accuracy: 0.058, Test loss: 5.322
# [9449/10000] User 9448 fut (LSTM multi-input)...
# [9448] Test accuracy: 0.045, Test loss: 6.305
# [9450/10000] User 9449 fut (LSTM multi-input)...
# [9449] Test accuracy: 0.173, Test loss: 5.109
# [9451/10000] User 9450 fut (LSTM multi-input)...
# [9450] Test accuracy: 0.466, Test loss: 2.292
# [9452/10000] User 9451 fut (LSTM multi-input)...
# [9451] Test accuracy: 0.239, Test loss: 3.474
# [9453/10000] User 9452 fut (LSTM multi-input)...
# [9452] Test accuracy: 0.129, Test loss: 6.218
# [9454/10000] User 9453 fut (LSTM multi-input)...
# [9453] Test accuracy: 0.209, Test loss: 4.649
# [9455/10000] User 9454 fut (LSTM multi-input)...
# [9454] Test accuracy: 0.360, Test loss: 2.281
# [9456/10000] User 9455 fut (LSTM multi-input)...
# [9455] Test accuracy: 0.408, Test loss: 4.107
# [9457/10000] User 9456 fut (LSTM multi-input)...
# [9456] Test accuracy: 0.072, Test loss: 5.700
# [9458/10000] User 9457 fut (LSTM multi-input)...
# [9457] Test accuracy: 0.029, Test loss: 5.715
# [9459/10000] User 9458 fut (LSTM multi-input)...
# [9458] Test accuracy: 0.081, Test loss: 5.294
# [9460/10000] User 9459 fut (LSTM multi-input)...
# [9459] Test accuracy: 0.352, Test loss: 2.419
# [9461/10000] User 9460 fut (LSTM multi-input)...
# [9460] Test accuracy: 0.094, Test loss: 4.951
# [9462/10000] User 9461 fut (LSTM multi-input)...
# [9461] Test accuracy: 0.141, Test loss: 4.271
# [9463/10000] User 9462 fut (LSTM multi-input)...
# [9462] Test accuracy: 0.329, Test loss: 2.762
# [9464/10000] User 9463 fut (LSTM multi-input)...
# [9463] Test accuracy: 0.081, Test loss: 6.136
# [9465/10000] User 9464 fut (LSTM multi-input)...
# [9464] Test accuracy: 0.562, Test loss: 2.250
# [9466/10000] User 9465 fut (LSTM multi-input)...
# [9465] Test accuracy: 0.086, Test loss: 5.519
# [9467/10000] User 9466 fut (LSTM multi-input)...
# [9466] Test accuracy: 0.030, Test loss: 5.869
# [9468/10000] User 9467 fut (LSTM multi-input)...
# [9467] Test accuracy: 0.393, Test loss: 3.575
# [9469/10000] User 9468 fut (LSTM multi-input)...
# [9468] Test accuracy: 0.270, Test loss: 3.506
# [9470/10000] User 9469 fut (LSTM multi-input)...
# [9469] Test accuracy: 0.217, Test loss: 4.731
# [9471/10000] User 9470 fut (LSTM multi-input)...
# [9470] Test accuracy: 0.087, Test loss: 5.480
# [9472/10000] User 9471 fut (LSTM multi-input)...
# [9471] Test accuracy: 0.142, Test loss: 4.288
# [9473/10000] User 9472 fut (LSTM multi-input)...
# [9472] Test accuracy: 0.215, Test loss: 4.430
# [9474/10000] User 9473 fut (LSTM multi-input)...
# [9473] Test accuracy: 0.158, Test loss: 3.867
# [9475/10000] User 9474 fut (LSTM multi-input)...
# [9474] Test accuracy: 0.409, Test loss: 2.488
# [9476/10000] User 9475 fut (LSTM multi-input)...
# [9475] Test accuracy: 0.089, Test loss: 5.160
# [9477/10000] User 9476 fut (LSTM multi-input)...
# [9476] Test accuracy: 0.102, Test loss: 4.723
# [9478/10000] User 9477 fut (LSTM multi-input)...
# [9477] Test accuracy: 0.164, Test loss: 5.264
# [9479/10000] User 9478 fut (LSTM multi-input)...
# [9478] Test accuracy: 0.177, Test loss: 2.946
# [9480/10000] User 9479 fut (LSTM multi-input)...
# [9479] Test accuracy: 0.415, Test loss: 2.015
# [9481/10000] User 9480 fut (LSTM multi-input)...
# [9480] Test accuracy: 0.086, Test loss: 4.466
# [9482/10000] User 9481 fut (LSTM multi-input)...
# [9481] Test accuracy: 0.049, Test loss: 3.827
# [9483/10000] User 9482 fut (LSTM multi-input)...
# [9482] Test accuracy: 0.184, Test loss: 4.601
# [9484/10000] User 9483 fut (LSTM multi-input)...
# [9483] Test accuracy: 0.420, Test loss: 2.133
# [9485/10000] User 9484 fut (LSTM multi-input)...
# [9484] Test accuracy: 0.165, Test loss: 3.751
# [9486/10000] User 9485 fut (LSTM multi-input)...
# [9485] Test accuracy: 0.171, Test loss: 5.267
# [9487/10000] User 9486 fut (LSTM multi-input)...
# [9486] Test accuracy: 0.339, Test loss: 3.094
# [9488/10000] User 9487 fut (LSTM multi-input)...
# [9487] Test accuracy: 0.120, Test loss: 4.478
# [9489/10000] User 9488 fut (LSTM multi-input)...
# [9488] Test accuracy: 0.453, Test loss: 2.425
# [9490/10000] User 9489 fut (LSTM multi-input)...
# [9489] Test accuracy: 0.168, Test loss: 4.357
# [9491/10000] User 9490 fut (LSTM multi-input)...
# [9490] Test accuracy: 0.500, Test loss: 2.071
# [9492/10000] User 9491 fut (LSTM multi-input)...
# [9491] Test accuracy: 0.538, Test loss: 2.789
# [9493/10000] User 9492 fut (LSTM multi-input)...
# [9492] Test accuracy: 0.159, Test loss: 4.980
# [9494/10000] User 9493 fut (LSTM multi-input)...
# [9493] Test accuracy: 0.211, Test loss: 4.488
# [9495/10000] User 9494 fut (LSTM multi-input)...
# [9494] Test accuracy: 0.285, Test loss: 3.025
# [9496/10000] User 9495 fut (LSTM multi-input)...
# [9495] Test accuracy: 0.123, Test loss: 5.188
# [9497/10000] User 9496 fut (LSTM multi-input)...
# [9496] Test accuracy: 0.174, Test loss: 5.339
# [9498/10000] User 9497 fut (LSTM multi-input)...
# [9497] Test accuracy: 0.058, Test loss: 5.924
# [9499/10000] User 9498 fut (LSTM multi-input)...
# [9498] Test accuracy: 0.535, Test loss: 1.279
# [9500/10000] User 9499 fut (LSTM multi-input)...
# [9499] Test accuracy: 0.267, Test loss: 3.128
# [9501/10000] User 9500 fut (LSTM multi-input)...
# [9500] Test accuracy: 0.100, Test loss: 4.261
# [9502/10000] User 9501 fut (LSTM multi-input)...
# [9501] Test accuracy: 0.045, Test loss: 6.100
# [9503/10000] User 9502 fut (LSTM multi-input)...
# [9502] Test accuracy: 0.045, Test loss: 6.051
# [9504/10000] User 9503 fut (LSTM multi-input)...
# [9503] Test accuracy: 0.187, Test loss: 4.793
# [9505/10000] User 9504 fut (LSTM multi-input)...
# [9504] Test accuracy: 0.521, Test loss: 2.988
# [9506/10000] User 9505 fut (LSTM multi-input)...
# [9505] Test accuracy: 0.415, Test loss: 2.865
# [9507/10000] User 9506 fut (LSTM multi-input)...
# [9506] Test accuracy: 0.028, Test loss: 6.030
# [9508/10000] User 9507 fut (LSTM multi-input)...
# [9507] Test accuracy: 0.201, Test loss: 6.014
# [9509/10000] User 9508 fut (LSTM multi-input)...
# [9508] Test accuracy: 0.090, Test loss: 4.907
# [9510/10000] User 9509 fut (LSTM multi-input)...
# [9509] Test accuracy: 0.166, Test loss: 4.403
# [9511/10000] User 9510 fut (LSTM multi-input)...
# [9510] Test accuracy: 0.047, Test loss: 6.036
# [9512/10000] User 9511 fut (LSTM multi-input)...
# [9511] Test accuracy: 0.051, Test loss: 6.159
# [9513/10000] User 9512 fut (LSTM multi-input)...
# [9512] Test accuracy: 0.039, Test loss: 5.658
# [9514/10000] User 9513 fut (LSTM multi-input)...
# [9513] Test accuracy: 0.367, Test loss: 3.047
# [9515/10000] User 9514 fut (LSTM multi-input)...
# [9514] Test accuracy: 0.153, Test loss: 4.118
# [9516/10000] User 9515 fut (LSTM multi-input)...
# [9515] Test accuracy: 0.372, Test loss: 3.175
# [9517/10000] User 9516 fut (LSTM multi-input)...
# [9516] Test accuracy: 0.096, Test loss: 6.030
# [9518/10000] User 9517 fut (LSTM multi-input)...
# [9517] Test accuracy: 0.315, Test loss: 3.151
# [9519/10000] User 9518 fut (LSTM multi-input)...
# [9518] Test accuracy: 0.417, Test loss: 2.810
# [9520/10000] User 9519 fut (LSTM multi-input)...
# [9519] Test accuracy: 0.000, Test loss: 5.780
# [9521/10000] User 9520 fut (LSTM multi-input)...
# [9520] Test accuracy: 0.473, Test loss: 2.430
# [9522/10000] User 9521 fut (LSTM multi-input)...
# [9521] Test accuracy: 0.283, Test loss: 2.464
# [9523/10000] User 9522 fut (LSTM multi-input)...
# [9522] Test accuracy: 0.058, Test loss: 4.088
# [9524/10000] User 9523 fut (LSTM multi-input)...
# [9523] Test accuracy: 0.277, Test loss: 3.951
# [9525/10000] User 9524 fut (LSTM multi-input)...
# [9524] Test accuracy: 0.340, Test loss: 2.153
# [9526/10000] User 9525 fut (LSTM multi-input)...
# [9525] Test accuracy: 0.427, Test loss: 3.036
# [9527/10000] User 9526 fut (LSTM multi-input)...
# [9526] Test accuracy: 0.298, Test loss: 3.290
# [9528/10000] User 9527 fut (LSTM multi-input)...
# [9527] Test accuracy: 0.560, Test loss: 3.358
# [9529/10000] User 9528 fut (LSTM multi-input)...
# [9528] Test accuracy: 0.034, Test loss: 5.831
# [9530/10000] User 9529 fut (LSTM multi-input)...
# [9529] Test accuracy: 0.136, Test loss: 5.786
# [9531/10000] User 9530 fut (LSTM multi-input)...
# [9530] Test accuracy: 0.115, Test loss: 4.779
# [9532/10000] User 9531 fut (LSTM multi-input)...
# [9531] Test accuracy: 0.173, Test loss: 4.707
# [9533/10000] User 9532 fut (LSTM multi-input)...
# [9532] Test accuracy: 0.453, Test loss: 1.869
# [9534/10000] User 9533 fut (LSTM multi-input)...
# [9533] Test accuracy: 0.045, Test loss: 5.007
# [9535/10000] User 9534 fut (LSTM multi-input)...
# [9534] Test accuracy: 0.143, Test loss: 4.780
# [9536/10000] User 9535 fut (LSTM multi-input)...
# [9535] Test accuracy: 0.132, Test loss: 5.992
# [9537/10000] User 9536 fut (LSTM multi-input)...
# [9536] Test accuracy: 0.365, Test loss: 2.866
# [9538/10000] User 9537 fut (LSTM multi-input)...
# [9537] Test accuracy: 0.358, Test loss: 3.077
# [9539/10000] User 9538 fut (LSTM multi-input)...
# [9538] Test accuracy: 0.293, Test loss: 3.337
# [9540/10000] User 9539 fut (LSTM multi-input)...
# [9539] Test accuracy: 0.071, Test loss: 3.651
# [9541/10000] User 9540 fut (LSTM multi-input)...
# [9540] Test accuracy: 0.378, Test loss: 2.749
# [9542/10000] User 9541 fut (LSTM multi-input)...
# [9541] Test accuracy: 0.430, Test loss: 3.345
# [9543/10000] User 9542 fut (LSTM multi-input)...
# [9542] Test accuracy: 0.000, Test loss: 5.773
# [9544/10000] User 9543 fut (LSTM multi-input)...
# [9543] Test accuracy: 0.143, Test loss: 4.557
# [9545/10000] User 9544 fut (LSTM multi-input)...
# [9544] Test accuracy: 0.313, Test loss: 3.670
# [9546/10000] User 9545 fut (LSTM multi-input)...
# [9545] Test accuracy: 0.556, Test loss: 2.216
# [9547/10000] User 9546 fut (LSTM multi-input)...
# [9546] Test accuracy: 0.231, Test loss: 4.780
# [9548/10000] User 9547 fut (LSTM multi-input)...
# [9547] Test accuracy: 0.427, Test loss: 2.116
# [9549/10000] User 9548 fut (LSTM multi-input)...
# [9548] Test accuracy: 0.052, Test loss: 5.916
# [9550/10000] User 9549 fut (LSTM multi-input)...
# [9549] Test accuracy: 0.047, Test loss: 5.757
# [9551/10000] User 9550 fut (LSTM multi-input)...
# [9550] Test accuracy: 0.111, Test loss: 5.968
# [9552/10000] User 9551 fut (LSTM multi-input)...
# [9551] Test accuracy: 0.118, Test loss: 5.344
# [9553/10000] User 9552 fut (LSTM multi-input)...
# [9552] Test accuracy: 0.000, Test loss: 6.584
# [9554/10000] User 9553 fut (LSTM multi-input)...
# [9553] Test accuracy: 0.199, Test loss: 5.058
# [9555/10000] User 9554 fut (LSTM multi-input)...
# [9554] Test accuracy: 0.071, Test loss: 5.698
# [9556/10000] User 9555 fut (LSTM multi-input)...
# [9555] Test accuracy: 0.371, Test loss: 2.898
# [9557/10000] User 9556 fut (LSTM multi-input)...
# [9556] Test accuracy: 0.292, Test loss: 4.565
# [9558/10000] User 9557 fut (LSTM multi-input)...
# [9557] Test accuracy: 0.408, Test loss: 3.178
# [9559/10000] User 9558 fut (LSTM multi-input)...
# [9558] Test accuracy: 0.217, Test loss: 3.227
# [9560/10000] User 9559 fut (LSTM multi-input)...
# [9559] Test accuracy: 0.199, Test loss: 4.521
# [9561/10000] User 9560 fut (LSTM multi-input)...
# [9560] Test accuracy: 0.333, Test loss: 3.242
# [9562/10000] User 9561 fut (LSTM multi-input)...
# [9561] Test accuracy: 0.374, Test loss: 1.915
# [9563/10000] User 9562 fut (LSTM multi-input)...
# [9562] Test accuracy: 0.387, Test loss: 1.762
# [9564/10000] User 9563 fut (LSTM multi-input)...
# [9563] Test accuracy: 0.046, Test loss: 5.907
# [9565/10000] User 9564 fut (LSTM multi-input)...
# [9564] Test accuracy: 0.302, Test loss: 3.481
# [9566/10000] User 9565 fut (LSTM multi-input)...
# [9565] Test accuracy: 0.433, Test loss: 3.104
# [9567/10000] User 9566 fut (LSTM multi-input)...
# [9566] Test accuracy: 0.673, Test loss: 1.768
# [9568/10000] User 9567 fut (LSTM multi-input)...
# [9567] Test accuracy: 0.255, Test loss: 3.417
# [9569/10000] User 9568 fut (LSTM multi-input)...
# [9568] Test accuracy: 0.062, Test loss: 5.875
# [9570/10000] User 9569 fut (LSTM multi-input)...
# [9569] Test accuracy: 0.619, Test loss: 1.933
# [9571/10000] User 9570 fut (LSTM multi-input)...
# [9570] Test accuracy: 0.155, Test loss: 3.780
# [9572/10000] User 9571 fut (LSTM multi-input)...
# [9571] Test accuracy: 0.346, Test loss: 3.209
# [9573/10000] User 9572 fut (LSTM multi-input)...
# [9572] Test accuracy: 0.348, Test loss: 3.206
# [9574/10000] User 9573 fut (LSTM multi-input)...
# [9573] Test accuracy: 0.297, Test loss: 3.237
# [9575/10000] User 9574 fut (LSTM multi-input)...
# [9574] Test accuracy: 0.102, Test loss: 5.933
# [9576/10000] User 9575 fut (LSTM multi-input)...
# [9575] Test accuracy: 0.123, Test loss: 4.900
# [9577/10000] User 9576 fut (LSTM multi-input)...
# [9576] Test accuracy: 0.323, Test loss: 3.576
# [9578/10000] User 9577 fut (LSTM multi-input)...
# [9577] Test accuracy: 0.291, Test loss: 4.047
# [9579/10000] User 9578 fut (LSTM multi-input)...
# [9578] Test accuracy: 0.308, Test loss: 3.775
# [9580/10000] User 9579 fut (LSTM multi-input)...
# [9579] Test accuracy: 0.268, Test loss: 4.116
# [9581/10000] User 9580 fut (LSTM multi-input)...
# [9580] Test accuracy: 0.324, Test loss: 3.461
# [9582/10000] User 9581 fut (LSTM multi-input)...
# [9581] Test accuracy: 0.195, Test loss: 3.958
# [9583/10000] User 9582 fut (LSTM multi-input)...
# [9582] Test accuracy: 0.328, Test loss: 3.714
# [9584/10000] User 9583 fut (LSTM multi-input)...
# [9583] Test accuracy: 0.356, Test loss: 3.461
# [9585/10000] User 9584 fut (LSTM multi-input)...
# [9584] Test accuracy: 0.019, Test loss: 6.170
# [9586/10000] User 9585 fut (LSTM multi-input)...
# [9585] Test accuracy: 0.211, Test loss: 4.396
# [9587/10000] User 9586 fut (LSTM multi-input)...
# [9586] Test accuracy: 0.115, Test loss: 5.438
# [9588/10000] User 9587 fut (LSTM multi-input)...
# [9587] Test accuracy: 0.157, Test loss: 4.457
# [9589/10000] User 9588 fut (LSTM multi-input)...
# [9588] Test accuracy: 0.207, Test loss: 4.101
# [9590/10000] User 9589 fut (LSTM multi-input)...
# [9589] Test accuracy: 0.134, Test loss: 5.194
# [9591/10000] User 9590 fut (LSTM multi-input)...
# [9590] Test accuracy: 0.190, Test loss: 4.880
# [9592/10000] User 9591 fut (LSTM multi-input)...
# [9591] Test accuracy: 0.231, Test loss: 3.590
# [9593/10000] User 9592 fut (LSTM multi-input)...
# [9592] Test accuracy: 0.080, Test loss: 5.509
# [9594/10000] User 9593 fut (LSTM multi-input)...
# [9593] Test accuracy: 0.050, Test loss: 5.882
# [9595/10000] User 9594 fut (LSTM multi-input)...
# [9594] Test accuracy: 0.074, Test loss: 6.185
# [9596/10000] User 9595 fut (LSTM multi-input)...
# [9595] Test accuracy: 0.248, Test loss: 3.331
# [9597/10000] User 9596 fut (LSTM multi-input)...
# [9596] Test accuracy: 0.269, Test loss: 3.585
# [9598/10000] User 9597 fut (LSTM multi-input)...
# [9597] Test accuracy: 0.056, Test loss: 6.092
# [9599/10000] User 9598 fut (LSTM multi-input)...
# [9598] Test accuracy: 0.298, Test loss: 3.146
# [9600/10000] User 9599 fut (LSTM multi-input)...
# [9599] Test accuracy: 0.226, Test loss: 4.987
# [9601/10000] User 9600 fut (LSTM multi-input)...
# [9600] Test accuracy: 0.213, Test loss: 4.287
# [9602/10000] User 9601 fut (LSTM multi-input)...
# [9601] Test accuracy: 0.170, Test loss: 3.342
# [9603/10000] User 9602 fut (LSTM multi-input)...
# [9602] Test accuracy: 0.085, Test loss: 5.316
# [9604/10000] User 9603 fut (LSTM multi-input)...
# [9603] Test accuracy: 0.265, Test loss: 2.978
# [9605/10000] User 9604 fut (LSTM multi-input)...
# [9604] Test accuracy: 0.124, Test loss: 5.104
# [9606/10000] User 9605 fut (LSTM multi-input)...
# [9605] Test accuracy: 0.194, Test loss: 4.045
# [9607/10000] User 9606 fut (LSTM multi-input)...
# [9606] Test accuracy: 0.294, Test loss: 4.228
# [9608/10000] User 9607 fut (LSTM multi-input)...
# [9607] Test accuracy: 0.483, Test loss: 1.610
# [9609/10000] User 9608 fut (LSTM multi-input)...
# [9608] Test accuracy: 0.185, Test loss: 4.788
# [9610/10000] User 9609 fut (LSTM multi-input)...
# [9609] Test accuracy: 0.257, Test loss: 2.912
# [9611/10000] User 9610 fut (LSTM multi-input)...
# [9610] Test accuracy: 0.464, Test loss: 2.958
# [9612/10000] User 9611 fut (LSTM multi-input)...
# [9611] Test accuracy: 0.077, Test loss: 5.586
# [9613/10000] User 9612 fut (LSTM multi-input)...
# [9612] Test accuracy: 0.042, Test loss: 5.772
# [9614/10000] User 9613 fut (LSTM multi-input)...
# [9613] Test accuracy: 0.383, Test loss: 3.142
# [9615/10000] User 9614 fut (LSTM multi-input)...
# [9614] Test accuracy: 0.364, Test loss: 3.415
# [9616/10000] User 9615 fut (LSTM multi-input)...
# [9615] Test accuracy: 0.080, Test loss: 5.936
# [9617/10000] User 9616 fut (LSTM multi-input)...
# [9616] Test accuracy: 0.295, Test loss: 1.986
# [9618/10000] User 9617 fut (LSTM multi-input)...
# [9617] Test accuracy: 0.215, Test loss: 3.813
# [9619/10000] User 9618 fut (LSTM multi-input)...
# [9618] Test accuracy: 0.130, Test loss: 5.077
# [9620/10000] User 9619 fut (LSTM multi-input)...
# [9619] Test accuracy: 0.104, Test loss: 3.873
# [9621/10000] User 9620 fut (LSTM multi-input)...
# [9620] Test accuracy: 0.186, Test loss: 4.206
# [9622/10000] User 9621 fut (LSTM multi-input)...
# [9621] Test accuracy: 0.152, Test loss: 4.788
# [9623/10000] User 9622 fut (LSTM multi-input)...
# [9622] Test accuracy: 0.133, Test loss: 4.831
# [9624/10000] User 9623 fut (LSTM multi-input)...
# [9623] Test accuracy: 0.115, Test loss: 4.685
# [9625/10000] User 9624 fut (LSTM multi-input)...
# [9624] Test accuracy: 0.427, Test loss: 2.567
# [9626/10000] User 9625 fut (LSTM multi-input)...
# [9625] Test accuracy: 0.120, Test loss: 4.502
# [9627/10000] User 9626 fut (LSTM multi-input)...
# [9626] Test accuracy: 0.512, Test loss: 2.639
# [9628/10000] User 9627 fut (LSTM multi-input)...
# [9627] Test accuracy: 0.050, Test loss: 6.067
# [9629/10000] User 9628 fut (LSTM multi-input)...
# [9628] Test accuracy: 0.115, Test loss: 4.700
# [9630/10000] User 9629 fut (LSTM multi-input)...
# [9629] Test accuracy: 0.318, Test loss: 2.586
# [9631/10000] User 9630 fut (LSTM multi-input)...
# [9630] Test accuracy: 0.144, Test loss: 5.260
# [9632/10000] User 9631 fut (LSTM multi-input)...
# [9631] Test accuracy: 0.158, Test loss: 5.222
# [9633/10000] User 9632 fut (LSTM multi-input)...
# [9632] Test accuracy: 0.224, Test loss: 4.284
# [9634/10000] User 9633 fut (LSTM multi-input)...
# [9633] Test accuracy: 0.500, Test loss: 1.881
# [9635/10000] User 9634 fut (LSTM multi-input)...
# [9634] Test accuracy: 0.364, Test loss: 2.800
# [9636/10000] User 9635 fut (LSTM multi-input)...
# [9635] Test accuracy: 0.102, Test loss: 5.322
# [9637/10000] User 9636 fut (LSTM multi-input)...
# [9636] Test accuracy: 0.265, Test loss: 2.996
# [9638/10000] User 9637 fut (LSTM multi-input)...
# [9637] Test accuracy: 0.388, Test loss: 2.306
# [9639/10000] User 9638 fut (LSTM multi-input)...
# [9638] Test accuracy: 0.226, Test loss: 3.341
# [9640/10000] User 9639 fut (LSTM multi-input)...
# [9639] Test accuracy: 0.183, Test loss: 5.168
# [9641/10000] User 9640 fut (LSTM multi-input)...
# [9640] Test accuracy: 0.130, Test loss: 4.460
# [9642/10000] User 9641 fut (LSTM multi-input)...
# [9641] Test accuracy: 0.204, Test loss: 4.243
# [9643/10000] User 9642 fut (LSTM multi-input)...
# [9642] Test accuracy: 0.126, Test loss: 4.843
# [9644/10000] User 9643 fut (LSTM multi-input)...
# [9643] Test accuracy: 0.445, Test loss: 3.437
# [9645/10000] User 9644 fut (LSTM multi-input)...
# [9644] Test accuracy: 0.405, Test loss: 4.169
# [9646/10000] User 9645 fut (LSTM multi-input)...
# [9645] Test accuracy: 0.496, Test loss: 3.807
# [9647/10000] User 9646 fut (LSTM multi-input)...
# [9646] Test accuracy: 0.161, Test loss: 5.279
# [9648/10000] User 9647 fut (LSTM multi-input)...
# [9647] Test accuracy: 0.190, Test loss: 4.678
# [9649/10000] User 9648 fut (LSTM multi-input)...
# [9648] Test accuracy: 0.223, Test loss: 4.855
# [9650/10000] User 9649 fut (LSTM multi-input)...
# [9649] Test accuracy: 0.079, Test loss: 4.040
# [9651/10000] User 9650 fut (LSTM multi-input)...
# [9650] Test accuracy: 0.274, Test loss: 3.795
# [9652/10000] User 9651 fut (LSTM multi-input)...
# [9651] Test accuracy: 0.089, Test loss: 5.679
# [9653/10000] User 9652 fut (LSTM multi-input)...
# [9652] Test accuracy: 0.407, Test loss: 3.073
# [9654/10000] User 9653 fut (LSTM multi-input)...
# [9653] Test accuracy: 0.365, Test loss: 2.919
# [9655/10000] User 9654 fut (LSTM multi-input)...
# [9654] Test accuracy: 0.188, Test loss: 4.433
# [9656/10000] User 9655 fut (LSTM multi-input)...
# [9655] Test accuracy: 0.229, Test loss: 3.953
# [9657/10000] User 9656 fut (LSTM multi-input)...
# [9656] Test accuracy: 0.084, Test loss: 4.457
# [9658/10000] User 9657 fut (LSTM multi-input)...
# [9657] Test accuracy: 0.337, Test loss: 2.943
# [9659/10000] User 9658 fut (LSTM multi-input)...
# [9658] Test accuracy: 0.176, Test loss: 4.237
# [9660/10000] User 9659 fut (LSTM multi-input)...
# [9659] Test accuracy: 0.378, Test loss: 2.600
# [9661/10000] User 9660 fut (LSTM multi-input)...
# [9660] Test accuracy: 0.257, Test loss: 3.827
# [9662/10000] User 9661 fut (LSTM multi-input)...
# [9661] Test accuracy: 0.103, Test loss: 5.558
# [9663/10000] User 9662 fut (LSTM multi-input)...
# [9662] Test accuracy: 0.669, Test loss: 2.155
# [9664/10000] User 9663 fut (LSTM multi-input)...
# [9663] Test accuracy: 0.057, Test loss: 4.966
# [9665/10000] User 9664 fut (LSTM multi-input)...
# [9664] Test accuracy: 0.508, Test loss: 2.089
# [9666/10000] User 9665 fut (LSTM multi-input)...
# [9665] Test accuracy: 0.317, Test loss: 3.653
# [9667/10000] User 9666 fut (LSTM multi-input)...
# [9666] Test accuracy: 0.296, Test loss: 2.336
# [9668/10000] User 9667 fut (LSTM multi-input)...
# [9667] Test accuracy: 0.206, Test loss: 6.149
# [9669/10000] User 9668 fut (LSTM multi-input)...
# [9668] Test accuracy: 0.267, Test loss: 3.296
# [9670/10000] User 9669 fut (LSTM multi-input)...
# [9669] Test accuracy: 0.359, Test loss: 2.967
# [9671/10000] User 9670 fut (LSTM multi-input)...
# [9670] Test accuracy: 0.183, Test loss: 3.773
# [9672/10000] User 9671 fut (LSTM multi-input)...
# [9671] Test accuracy: 0.080, Test loss: 5.108
# [9673/10000] User 9672 fut (LSTM multi-input)...
# [9672] Test accuracy: 0.167, Test loss: 4.096
# [9674/10000] User 9673 fut (LSTM multi-input)...
# [9673] Test accuracy: 0.346, Test loss: 3.229
# [9675/10000] User 9674 fut (LSTM multi-input)...
# [9674] Test accuracy: 0.420, Test loss: 2.651
# [9676/10000] User 9675 fut (LSTM multi-input)...
# [9675] Test accuracy: 0.352, Test loss: 3.546
# [9677/10000] User 9676 fut (LSTM multi-input)...
# [9676] Test accuracy: 0.150, Test loss: 3.803
# [9678/10000] User 9677 fut (LSTM multi-input)...
# [9677] Test accuracy: 0.502, Test loss: 2.414
# [9679/10000] User 9678 fut (LSTM multi-input)...
# [9678] Test accuracy: 0.142, Test loss: 4.766
# [9680/10000] User 9679 fut (LSTM multi-input)...
# [9679] Test accuracy: 0.271, Test loss: 2.470
# [9681/10000] User 9680 fut (LSTM multi-input)...
# [9680] Test accuracy: 0.410, Test loss: 1.606
# [9682/10000] User 9681 fut (LSTM multi-input)...
# [9681] Test accuracy: 0.184, Test loss: 4.009
# [9683/10000] User 9682 fut (LSTM multi-input)...
# [9682] Test accuracy: 0.279, Test loss: 4.181
# [9684/10000] User 9683 fut (LSTM multi-input)...
# [9683] Test accuracy: 0.282, Test loss: 4.446
# [9685/10000] User 9684 fut (LSTM multi-input)...
# [9684] Test accuracy: 0.414, Test loss: 2.175
# [9686/10000] User 9685 fut (LSTM multi-input)...
# [9685] Test accuracy: 0.135, Test loss: 4.821
# [9687/10000] User 9686 fut (LSTM multi-input)...
# [9686] Test accuracy: 0.215, Test loss: 3.886
# [9688/10000] User 9687 fut (LSTM multi-input)...
# [9687] Test accuracy: 0.402, Test loss: 2.869
# [9689/10000] User 9688 fut (LSTM multi-input)...
# [9688] Test accuracy: 0.197, Test loss: 5.022
# [9690/10000] User 9689 fut (LSTM multi-input)...
# [9689] Test accuracy: 0.489, Test loss: 1.956
# [9691/10000] User 9690 fut (LSTM multi-input)...
# [9690] Test accuracy: 0.285, Test loss: 2.830
# [9692/10000] User 9691 fut (LSTM multi-input)...
# [9691] Test accuracy: 0.271, Test loss: 4.455
# [9693/10000] User 9692 fut (LSTM multi-input)...
# [9692] Test accuracy: 0.462, Test loss: 1.910
# [9694/10000] User 9693 fut (LSTM multi-input)...
# [9693] Test accuracy: 0.119, Test loss: 4.487
# [9695/10000] User 9694 fut (LSTM multi-input)...
# [9694] Test accuracy: 0.163, Test loss: 4.532
# [9696/10000] User 9695 fut (LSTM multi-input)...
# [9695] Test accuracy: 0.072, Test loss: 5.374
# [9697/10000] User 9696 fut (LSTM multi-input)...
# [9696] Test accuracy: 0.036, Test loss: 5.790
# [9698/10000] User 9697 fut (LSTM multi-input)...
# [9697] Test accuracy: 0.316, Test loss: 2.668
# [9699/10000] User 9698 fut (LSTM multi-input)...
# [9698] Test accuracy: 0.360, Test loss: 2.616
# [9700/10000] User 9699 fut (LSTM multi-input)...
# [9699] Test accuracy: 0.085, Test loss: 5.304
# [9701/10000] User 9700 fut (LSTM multi-input)...
# [9700] Test accuracy: 0.024, Test loss: 4.873
# [9702/10000] User 9701 fut (LSTM multi-input)...
# [9701] Test accuracy: 0.209, Test loss: 3.464
# [9703/10000] User 9702 fut (LSTM multi-input)...
# [9702] Test accuracy: 0.337, Test loss: 2.785
# [9704/10000] User 9703 fut (LSTM multi-input)...
# [9703] Test accuracy: 0.113, Test loss: 5.026
# [9705/10000] User 9704 fut (LSTM multi-input)...
# [9704] Test accuracy: 0.068, Test loss: 5.930
# [9706/10000] User 9705 fut (LSTM multi-input)...
# [9705] Test accuracy: 0.304, Test loss: 3.712
# [9707/10000] User 9706 fut (LSTM multi-input)...
# [9706] Test accuracy: 0.471, Test loss: 2.239
# [9708/10000] User 9707 fut (LSTM multi-input)...
# [9707] Test accuracy: 0.164, Test loss: 4.437
# [9709/10000] User 9708 fut (LSTM multi-input)...
# [9708] Test accuracy: 0.223, Test loss: 3.538
# [9710/10000] User 9709 fut (LSTM multi-input)...
# [9709] Test accuracy: 0.546, Test loss: 2.434
# [9711/10000] User 9710 fut (LSTM multi-input)...
# [9710] Test accuracy: 0.270, Test loss: 3.879
# [9712/10000] User 9711 fut (LSTM multi-input)...
# [9711] Test accuracy: 0.194, Test loss: 5.111
# [9713/10000] User 9712 fut (LSTM multi-input)...
# [9712] Test accuracy: 0.062, Test loss: 5.871
# [9714/10000] User 9713 fut (LSTM multi-input)...
# [9713] Test accuracy: 0.272, Test loss: 4.249
# [9715/10000] User 9714 fut (LSTM multi-input)...
# [9714] Test accuracy: 0.079, Test loss: 5.597
# [9716/10000] User 9715 fut (LSTM multi-input)...
# [9715] Test accuracy: 0.219, Test loss: 4.322
# [9717/10000] User 9716 fut (LSTM multi-input)...
# [9716] Test accuracy: 0.055, Test loss: 5.535
# [9718/10000] User 9717 fut (LSTM multi-input)...
# [9717] Test accuracy: 0.670, Test loss: 1.578
# [9719/10000] User 9718 fut (LSTM multi-input)...
# [9718] Test accuracy: 0.204, Test loss: 3.929
# [9720/10000] User 9719 fut (LSTM multi-input)...
# [9719] Test accuracy: 0.213, Test loss: 3.442
# [9721/10000] User 9720 fut (LSTM multi-input)...
# [9720] Test accuracy: 0.257, Test loss: 4.733
# [9722/10000] User 9721 fut (LSTM multi-input)...
# [9721] Test accuracy: 0.105, Test loss: 4.243
# [9723/10000] User 9722 fut (LSTM multi-input)...
# [9722] Test accuracy: 0.080, Test loss: 4.707
# [9724/10000] User 9723 fut (LSTM multi-input)...
# [9723] Test accuracy: 0.400, Test loss: 2.779
# [9725/10000] User 9724 fut (LSTM multi-input)...
# [9724] Test accuracy: 0.337, Test loss: 2.368
# [9726/10000] User 9725 fut (LSTM multi-input)...
# [9725] Test accuracy: 0.333, Test loss: 3.538
# [9727/10000] User 9726 fut (LSTM multi-input)...
# [9726] Test accuracy: 0.095, Test loss: 5.574
# [9728/10000] User 9727 fut (LSTM multi-input)...
# [9727] Test accuracy: 0.217, Test loss: 4.074
# [9729/10000] User 9728 fut (LSTM multi-input)...
# [9728] Test accuracy: 0.167, Test loss: 5.026
# [9730/10000] User 9729 fut (LSTM multi-input)...
# [9729] Test accuracy: 0.352, Test loss: 2.664
# [9731/10000] User 9730 fut (LSTM multi-input)...
# [9730] Test accuracy: 0.447, Test loss: 3.232
# [9732/10000] User 9731 fut (LSTM multi-input)...
# [9731] Test accuracy: 0.155, Test loss: 5.485
# [9733/10000] User 9732 fut (LSTM multi-input)...
# [9732] Test accuracy: 0.217, Test loss: 4.090
# [9734/10000] User 9733 fut (LSTM multi-input)...
# [9733] Test accuracy: 0.076, Test loss: 5.727
# [9735/10000] User 9734 fut (LSTM multi-input)...
# [9734] Test accuracy: 0.053, Test loss: 5.967
# [9736/10000] User 9735 fut (LSTM multi-input)...
# [9735] Test accuracy: 0.227, Test loss: 3.752
# [9737/10000] User 9736 fut (LSTM multi-input)...
# [9736] Test accuracy: 0.102, Test loss: 5.787
# [9738/10000] User 9737 fut (LSTM multi-input)...
# [9737] Test accuracy: 0.448, Test loss: 1.589
# [9739/10000] User 9738 fut (LSTM multi-input)...
# [9738] Test accuracy: 0.046, Test loss: 5.261
# [9740/10000] User 9739 fut (LSTM multi-input)...
# [9739] Test accuracy: 0.200, Test loss: 4.938
# [9741/10000] User 9740 fut (LSTM multi-input)...
# [9740] Test accuracy: 0.100, Test loss: 5.806
# [9742/10000] User 9741 fut (LSTM multi-input)...
# [9741] Test accuracy: 0.233, Test loss: 3.484
# [9743/10000] User 9742 fut (LSTM multi-input)...
# [9742] Test accuracy: 0.365, Test loss: 3.163
# [9744/10000] User 9743 fut (LSTM multi-input)...
# [9743] Test accuracy: 0.355, Test loss: 4.229
# [9745/10000] User 9744 fut (LSTM multi-input)...
# [9744] Test accuracy: 0.026, Test loss: 5.607
# [9746/10000] User 9745 fut (LSTM multi-input)...
# [9745] Test accuracy: 0.146, Test loss: 3.541
# [9747/10000] User 9746 fut (LSTM multi-input)...
# [9746] Test accuracy: 0.452, Test loss: 2.885
# [9748/10000] User 9747 fut (LSTM multi-input)...
# [9747] Test accuracy: 0.538, Test loss: 1.761
# [9749/10000] User 9748 fut (LSTM multi-input)...
# [9748] Test accuracy: 0.119, Test loss: 5.270
# [9750/10000] User 9749 fut (LSTM multi-input)...
# [9749] Test accuracy: 0.358, Test loss: 2.329
# [9751/10000] User 9750 fut (LSTM multi-input)...
# [9750] Test accuracy: 0.542, Test loss: 1.747
# [9752/10000] User 9751 fut (LSTM multi-input)...
# [9751] Test accuracy: 0.278, Test loss: 3.472
# [9753/10000] User 9752 fut (LSTM multi-input)...
# [9752] Test accuracy: 0.029, Test loss: 6.210
# [9754/10000] User 9753 fut (LSTM multi-input)...
# [9753] Test accuracy: 0.269, Test loss: 3.781
# [9755/10000] User 9754 fut (LSTM multi-input)...
# [9754] Test accuracy: 0.060, Test loss: 6.169
# [9756/10000] User 9755 fut (LSTM multi-input)...
# [9755] Test accuracy: 0.193, Test loss: 4.595
# [9757/10000] User 9756 fut (LSTM multi-input)...
# [9756] Test accuracy: 0.057, Test loss: 5.786
# [9758/10000] User 9757 fut (LSTM multi-input)...
# [9757] Test accuracy: 0.214, Test loss: 4.093
# [9759/10000] User 9758 fut (LSTM multi-input)...
# [9758] Test accuracy: 0.147, Test loss: 4.659
# [9760/10000] User 9759 fut (LSTM multi-input)...
# [9759] Test accuracy: 0.414, Test loss: 2.307
# [9761/10000] User 9760 fut (LSTM multi-input)...
# [9760] Test accuracy: 0.166, Test loss: 5.109
# [9762/10000] User 9761 fut (LSTM multi-input)...
# [9761] Test accuracy: 0.316, Test loss: 3.139
# [9763/10000] User 9762 fut (LSTM multi-input)...
# [9762] Test accuracy: 0.351, Test loss: 3.233
# [9764/10000] User 9763 fut (LSTM multi-input)...
# [9763] Test accuracy: 0.280, Test loss: 4.359
# [9765/10000] User 9764 fut (LSTM multi-input)...
# [9764] Test accuracy: 0.067, Test loss: 5.757
# [9766/10000] User 9765 fut (LSTM multi-input)...
# [9765] Test accuracy: 0.218, Test loss: 5.068
# [9767/10000] User 9766 fut (LSTM multi-input)...
# [9766] Test accuracy: 0.160, Test loss: 4.901
# [9768/10000] User 9767 fut (LSTM multi-input)...
# [9767] Test accuracy: 0.403, Test loss: 4.144
# [9769/10000] User 9768 fut (LSTM multi-input)...
# [9768] Test accuracy: 0.372, Test loss: 3.385
# [9770/10000] User 9769 fut (LSTM multi-input)...
# [9769] Test accuracy: 0.217, Test loss: 4.191
# [9771/10000] User 9770 fut (LSTM multi-input)...
# [9770] Test accuracy: 0.322, Test loss: 3.040
# [9772/10000] User 9771 fut (LSTM multi-input)...
# [9771] Test accuracy: 0.364, Test loss: 4.422
# [9773/10000] User 9772 fut (LSTM multi-input)...
# [9772] Test accuracy: 0.070, Test loss: 5.362
# [9774/10000] User 9773 fut (LSTM multi-input)...
# [9773] Test accuracy: 0.442, Test loss: 3.040
# [9775/10000] User 9774 fut (LSTM multi-input)...
# [9774] Test accuracy: 0.245, Test loss: 4.656
# [9776/10000] User 9775 fut (LSTM multi-input)...
# [9775] Test accuracy: 0.605, Test loss: 2.564
# [9777/10000] User 9776 fut (LSTM multi-input)...
# [9776] Test accuracy: 0.350, Test loss: 2.394
# [9778/10000] User 9777 fut (LSTM multi-input)...
# [9777] Test accuracy: 0.351, Test loss: 3.602
# [9779/10000] User 9778 fut (LSTM multi-input)...
# [9778] Test accuracy: 0.606, Test loss: 1.784
# [9780/10000] User 9779 fut (LSTM multi-input)...
# [9779] Test accuracy: 0.436, Test loss: 2.922
# [9781/10000] User 9780 fut (LSTM multi-input)...
# [9780] Test accuracy: 0.240, Test loss: 3.931
# [9782/10000] User 9781 fut (LSTM multi-input)...
# [9781] Test accuracy: 0.060, Test loss: 6.604
# [9783/10000] User 9782 fut (LSTM multi-input)...
# [9782] Test accuracy: 0.167, Test loss: 4.231
# [9784/10000] User 9783 fut (LSTM multi-input)...
# [9783] Test accuracy: 0.474, Test loss: 2.423
# [9785/10000] User 9784 fut (LSTM multi-input)...
# [9784] Test accuracy: 0.396, Test loss: 2.687
# [9786/10000] User 9785 fut (LSTM multi-input)...
# [9785] Test accuracy: 0.183, Test loss: 4.420
# [9787/10000] User 9786 fut (LSTM multi-input)...
# [9786] Test accuracy: 0.595, Test loss: 1.321
# [9788/10000] User 9787 fut (LSTM multi-input)...
# [9787] Test accuracy: 0.206, Test loss: 4.079
# [9789/10000] User 9788 fut (LSTM multi-input)...
# [9788] Test accuracy: 0.255, Test loss: 2.773
# [9790/10000] User 9789 fut (LSTM multi-input)...
# [9789] Test accuracy: 0.253, Test loss: 3.253
# [9791/10000] User 9790 fut (LSTM multi-input)...
# [9790] Test accuracy: 0.267, Test loss: 4.373
# [9792/10000] User 9791 fut (LSTM multi-input)...
# [9791] Test accuracy: 0.283, Test loss: 4.505
# [9793/10000] User 9792 fut (LSTM multi-input)...
# [9792] Test accuracy: 0.298, Test loss: 3.271
# [9794/10000] User 9793 fut (LSTM multi-input)...
# [9793] Test accuracy: 0.278, Test loss: 3.187
# [9795/10000] User 9794 fut (LSTM multi-input)...
# [9794] Test accuracy: 0.179, Test loss: 4.169
# [9796/10000] User 9795 fut (LSTM multi-input)...
# [9795] Test accuracy: 0.688, Test loss: 1.761
# [9797/10000] User 9796 fut (LSTM multi-input)...
# [9796] Test accuracy: 0.327, Test loss: 3.726
# [9798/10000] User 9797 fut (LSTM multi-input)...
# [9797] Test accuracy: 0.376, Test loss: 1.996
# [9799/10000] User 9798 fut (LSTM multi-input)...
# [9798] Test accuracy: 0.006, Test loss: 5.551
# [9800/10000] User 9799 fut (LSTM multi-input)...
# [9799] Test accuracy: 0.228, Test loss: 4.632
# [9801/10000] User 9800 fut (LSTM multi-input)...
# [9800] Test accuracy: 0.608, Test loss: 2.122
# [9802/10000] User 9801 fut (LSTM multi-input)...
# [9801] Test accuracy: 0.230, Test loss: 4.478
# [9803/10000] User 9802 fut (LSTM multi-input)...
# [9802] Test accuracy: 0.344, Test loss: 3.641
# [9804/10000] User 9803 fut (LSTM multi-input)...
# [9803] Test accuracy: 0.329, Test loss: 3.680
# [9805/10000] User 9804 fut (LSTM multi-input)...
# [9804] Test accuracy: 0.281, Test loss: 3.315
# [9806/10000] User 9805 fut (LSTM multi-input)...
# [9805] Test accuracy: 0.184, Test loss: 4.337
# [9807/10000] User 9806 fut (LSTM multi-input)...
# [9806] Test accuracy: 0.269, Test loss: 3.254
# [9808/10000] User 9807 fut (LSTM multi-input)...
# [9807] Test accuracy: 0.421, Test loss: 3.603
# [9809/10000] User 9808 fut (LSTM multi-input)...
# [9808] Test accuracy: 0.390, Test loss: 2.261
# [9810/10000] User 9809 fut (LSTM multi-input)...
# [9809] Test accuracy: 0.210, Test loss: 3.710
# [9811/10000] User 9810 fut (LSTM multi-input)...
# [9810] Test accuracy: 0.346, Test loss: 2.720
# [9812/10000] User 9811 fut (LSTM multi-input)...
# [9811] Test accuracy: 0.255, Test loss: 3.379
# [9813/10000] User 9812 fut (LSTM multi-input)...
# [9812] Test accuracy: 0.195, Test loss: 3.390
# [9814/10000] User 9813 fut (LSTM multi-input)...
# [9813] Test accuracy: 0.071, Test loss: 5.162
# [9815/10000] User 9814 fut (LSTM multi-input)...
# [9814] Test accuracy: 0.211, Test loss: 3.952
# [9816/10000] User 9815 fut (LSTM multi-input)...
# [9815] Test accuracy: 0.239, Test loss: 4.334
# [9817/10000] User 9816 fut (LSTM multi-input)...
# [9816] Test accuracy: 0.333, Test loss: 2.986
# [9818/10000] User 9817 fut (LSTM multi-input)...
# [9817] Test accuracy: 0.332, Test loss: 3.450
# [9819/10000] User 9818 fut (LSTM multi-input)...
# [9818] Test accuracy: 0.418, Test loss: 2.316
# [9820/10000] User 9819 fut (LSTM multi-input)...
# [9819] Test accuracy: 0.126, Test loss: 5.139
# [9821/10000] User 9820 fut (LSTM multi-input)...
# [9820] Test accuracy: 0.446, Test loss: 1.702
# [9822/10000] User 9821 fut (LSTM multi-input)...
# [9821] Test accuracy: 0.127, Test loss: 4.934
# [9823/10000] User 9822 fut (LSTM multi-input)...
# [9822] Test accuracy: 0.019, Test loss: 4.546
# [9824/10000] User 9823 fut (LSTM multi-input)...
# [9823] Test accuracy: 0.242, Test loss: 4.159
# [9825/10000] User 9824 fut (LSTM multi-input)...
# [9824] Test accuracy: 0.096, Test loss: 5.952
# [9826/10000] User 9825 fut (LSTM multi-input)...
# [9825] Test accuracy: 0.141, Test loss: 5.248
# [9827/10000] User 9826 fut (LSTM multi-input)...
# [9826] Test accuracy: 0.141, Test loss: 3.702
# [9828/10000] User 9827 fut (LSTM multi-input)...
# [9827] Test accuracy: 0.128, Test loss: 4.554
# [9829/10000] User 9828 fut (LSTM multi-input)...
# [9828] Test accuracy: 0.203, Test loss: 4.486
# [9830/10000] User 9829 fut (LSTM multi-input)...
# [9829] Test accuracy: 0.087, Test loss: 5.993
# [9831/10000] User 9830 fut (LSTM multi-input)...
# [9830] Test accuracy: 0.167, Test loss: 2.970
# [9832/10000] User 9831 fut (LSTM multi-input)...
# [9831] Test accuracy: 0.238, Test loss: 3.613
# [9833/10000] User 9832 fut (LSTM multi-input)...
# [9832] Test accuracy: 0.450, Test loss: 3.585
# [9834/10000] User 9833 fut (LSTM multi-input)...
# [9833] Test accuracy: 0.330, Test loss: 2.896
# [9835/10000] User 9834 fut (LSTM multi-input)...
# [9834] Test accuracy: 0.136, Test loss: 4.576
# [9836/10000] User 9835 fut (LSTM multi-input)...
# [9835] Test accuracy: 0.338, Test loss: 3.628
# [9837/10000] User 9836 fut (LSTM multi-input)...
# [9836] Test accuracy: 0.401, Test loss: 2.400
# [9838/10000] User 9837 fut (LSTM multi-input)...
# [9837] Test accuracy: 0.455, Test loss: 2.907
# [9839/10000] User 9838 fut (LSTM multi-input)...
# [9838] Test accuracy: 0.105, Test loss: 6.227
# [9840/10000] User 9839 fut (LSTM multi-input)...
# [9839] Test accuracy: 0.155, Test loss: 5.586
# [9841/10000] User 9840 fut (LSTM multi-input)...
# [9840] Test accuracy: 0.022, Test loss: 6.662
# [9842/10000] User 9841 fut (LSTM multi-input)...
# [9841] Test accuracy: 0.081, Test loss: 3.690
# [9843/10000] User 9842 fut (LSTM multi-input)...
# [9842] Test accuracy: 0.184, Test loss: 5.403
# [9844/10000] User 9843 fut (LSTM multi-input)...
# [9843] Test accuracy: 0.286, Test loss: 3.914
# [9845/10000] User 9844 fut (LSTM multi-input)...
# [9844] Test accuracy: 0.098, Test loss: 5.276
# [9846/10000] User 9845 fut (LSTM multi-input)...
# [9845] Test accuracy: 0.084, Test loss: 6.051
# [9847/10000] User 9846 fut (LSTM multi-input)...
# [9846] Test accuracy: 0.367, Test loss: 4.081
# [9848/10000] User 9847 fut (LSTM multi-input)...
# [9847] Test accuracy: 0.286, Test loss: 3.073
# [9849/10000] User 9848 fut (LSTM multi-input)...
# [9848] Test accuracy: 0.394, Test loss: 2.125
# [9850/10000] User 9849 fut (LSTM multi-input)...
# [9849] Test accuracy: 0.239, Test loss: 3.344
# [9851/10000] User 9850 fut (LSTM multi-input)...
# [9850] Test accuracy: 0.176, Test loss: 5.163
# [9852/10000] User 9851 fut (LSTM multi-input)...
# [9851] Test accuracy: 0.174, Test loss: 3.951
# [9853/10000] User 9852 fut (LSTM multi-input)...
# [9852] Test accuracy: 0.641, Test loss: 2.206
# [9854/10000] User 9853 fut (LSTM multi-input)...
# [9853] Test accuracy: 0.086, Test loss: 5.404
# [9855/10000] User 9854 fut (LSTM multi-input)...
# [9854] Test accuracy: 0.318, Test loss: 3.510
# [9856/10000] User 9855 fut (LSTM multi-input)...
# [9855] Test accuracy: 0.189, Test loss: 4.019
# [9857/10000] User 9856 fut (LSTM multi-input)...
# [9856] Test accuracy: 0.704, Test loss: 1.738
# [9858/10000] User 9857 fut (LSTM multi-input)...
# [9857] Test accuracy: 0.406, Test loss: 2.676
# [9859/10000] User 9858 fut (LSTM multi-input)...
# [9858] Test accuracy: 0.268, Test loss: 2.933
# [9860/10000] User 9859 fut (LSTM multi-input)...
# [9859] Test accuracy: 0.251, Test loss: 3.143
# [9861/10000] User 9860 fut (LSTM multi-input)...
# [9860] Test accuracy: 0.386, Test loss: 1.867
# [9862/10000] User 9861 fut (LSTM multi-input)...
# [9861] Test accuracy: 0.190, Test loss: 4.274
# [9863/10000] User 9862 fut (LSTM multi-input)...
# [9862] Test accuracy: 0.299, Test loss: 3.369
# [9864/10000] User 9863 fut (LSTM multi-input)...
# [9863] Test accuracy: 0.146, Test loss: 4.637
# [9865/10000] User 9864 fut (LSTM multi-input)...
# [9864] Test accuracy: 0.225, Test loss: 5.189
# [9866/10000] User 9865 fut (LSTM multi-input)...
# [9865] Test accuracy: 0.046, Test loss: 6.413
# [9867/10000] User 9866 fut (LSTM multi-input)...
# [9866] Test accuracy: 0.178, Test loss: 4.862
# [9868/10000] User 9867 fut (LSTM multi-input)...
# [9867] Test accuracy: 0.068, Test loss: 4.998
# [9869/10000] User 9868 fut (LSTM multi-input)...
# [9868] Test accuracy: 0.283, Test loss: 3.088
# [9870/10000] User 9869 fut (LSTM multi-input)...
# [9869] Test accuracy: 0.396, Test loss: 2.628
# [9871/10000] User 9870 fut (LSTM multi-input)...
# [9870] Test accuracy: 0.464, Test loss: 2.523
# [9872/10000] User 9871 fut (LSTM multi-input)...
# [9871] Test accuracy: 0.119, Test loss: 5.355
# [9873/10000] User 9872 fut (LSTM multi-input)...
# [9872] Test accuracy: 0.262, Test loss: 3.739
# [9874/10000] User 9873 fut (LSTM multi-input)...
# [9873] Test accuracy: 0.113, Test loss: 5.530
# [9875/10000] User 9874 fut (LSTM multi-input)...
# [9874] Test accuracy: 0.145, Test loss: 4.919
# [9876/10000] User 9875 fut (LSTM multi-input)...
# [9875] Test accuracy: 0.433, Test loss: 2.802
# [9877/10000] User 9876 fut (LSTM multi-input)...
# [9876] Test accuracy: 0.116, Test loss: 5.136
# [9878/10000] User 9877 fut (LSTM multi-input)...
# [9877] Test accuracy: 0.318, Test loss: 2.687
# [9879/10000] User 9878 fut (LSTM multi-input)...
# [9878] Test accuracy: 0.345, Test loss: 2.877
# [9880/10000] User 9879 fut (LSTM multi-input)...
# [9879] Test accuracy: 0.139, Test loss: 4.453
# [9881/10000] User 9880 fut (LSTM multi-input)...
# [9880] Test accuracy: 0.349, Test loss: 3.946
# [9882/10000] User 9881 fut (LSTM multi-input)...
# [9881] Test accuracy: 0.093, Test loss: 5.292
# [9883/10000] User 9882 fut (LSTM multi-input)...
# [9882] Test accuracy: 0.037, Test loss: 5.423
# [9884/10000] User 9883 fut (LSTM multi-input)...
# [9883] Test accuracy: 0.304, Test loss: 2.588
# [9885/10000] User 9884 fut (LSTM multi-input)...
# [9884] Test accuracy: 0.089, Test loss: 5.530
# [9886/10000] User 9885 fut (LSTM multi-input)...
# [9885] Test accuracy: 0.269, Test loss: 3.076
# [9887/10000] User 9886 fut (LSTM multi-input)...
# [9886] Test accuracy: 0.604, Test loss: 1.718
# [9888/10000] User 9887 fut (LSTM multi-input)...
# [9887] Test accuracy: 0.246, Test loss: 3.977
# [9889/10000] User 9888 fut (LSTM multi-input)...
# [9888] Test accuracy: 0.426, Test loss: 3.058
# [9890/10000] User 9889 fut (LSTM multi-input)...
# [9889] Test accuracy: 0.539, Test loss: 2.602
# [9891/10000] User 9890 fut (LSTM multi-input)...
# [9890] Test accuracy: 0.102, Test loss: 5.057
# [9892/10000] User 9891 fut (LSTM multi-input)...
# [9891] Test accuracy: 0.211, Test loss: 4.138
# [9893/10000] User 9892 fut (LSTM multi-input)...
# [9892] Test accuracy: 0.480, Test loss: 2.288
# [9894/10000] User 9893 fut (LSTM multi-input)...
# [9893] Test accuracy: 0.203, Test loss: 4.139
# [9895/10000] User 9894 fut (LSTM multi-input)...
# [9894] Test accuracy: 0.138, Test loss: 5.032
# [9896/10000] User 9895 fut (LSTM multi-input)...
# [9895] Test accuracy: 0.115, Test loss: 4.623
# [9897/10000] User 9896 fut (LSTM multi-input)...
# [9896] Test accuracy: 0.539, Test loss: 2.306
# [9898/10000] User 9897 fut (LSTM multi-input)...
# [9897] Test accuracy: 0.541, Test loss: 2.933
# [9899/10000] User 9898 fut (LSTM multi-input)...
# [9898] Test accuracy: 0.000, Test loss: 6.507
# [9900/10000] User 9899 fut (LSTM multi-input)...
# [9899] Test accuracy: 0.283, Test loss: 4.633
# [9901/10000] User 9900 fut (LSTM multi-input)...
# [9900] Test accuracy: 0.309, Test loss: 4.044
# [9902/10000] User 9901 fut (LSTM multi-input)...
# [9901] Test accuracy: 0.151, Test loss: 5.237
# [9903/10000] User 9902 fut (LSTM multi-input)...
# [9902] Test accuracy: 0.161, Test loss: 3.626
# [9904/10000] User 9903 fut (LSTM multi-input)...
# [9903] Test accuracy: 0.416, Test loss: 2.066
# [9905/10000] User 9904 fut (LSTM multi-input)...
# [9904] Test accuracy: 0.412, Test loss: 3.757
# [9906/10000] User 9905 fut (LSTM multi-input)...
# [9905] Test accuracy: 0.260, Test loss: 2.593
# [9907/10000] User 9906 fut (LSTM multi-input)...
# [9906] Test accuracy: 0.379, Test loss: 3.013
# [9908/10000] User 9907 fut (LSTM multi-input)...
# [9907] Test accuracy: 0.153, Test loss: 3.879
# [9909/10000] User 9908 fut (LSTM multi-input)...
# [9908] Test accuracy: 0.042, Test loss: 5.508
# [9910/10000] User 9909 fut (LSTM multi-input)...
# [9909] Test accuracy: 0.326, Test loss: 3.345
# [9911/10000] User 9910 fut (LSTM multi-input)...
# [9910] Test accuracy: 0.580, Test loss: 1.834
# [9912/10000] User 9911 fut (LSTM multi-input)...
# [9911] Test accuracy: 0.038, Test loss: 6.250
# [9913/10000] User 9912 fut (LSTM multi-input)...
# [9912] Test accuracy: 0.014, Test loss: 5.952
# [9914/10000] User 9913 fut (LSTM multi-input)...
# [9913] Test accuracy: 0.085, Test loss: 6.283
# [9915/10000] User 9914 fut (LSTM multi-input)...
# [9914] Test accuracy: 0.046, Test loss: 5.347
# [9916/10000] User 9915 fut (LSTM multi-input)...
# [9915] Test accuracy: 0.071, Test loss: 5.590
# [9917/10000] User 9916 fut (LSTM multi-input)...
# [9916] Test accuracy: 0.177, Test loss: 5.296
# [9918/10000] User 9917 fut (LSTM multi-input)...
# [9917] Test accuracy: 0.052, Test loss: 5.960
# [9919/10000] User 9918 fut (LSTM multi-input)...
# [9918] Test accuracy: 0.480, Test loss: 2.806
# [9920/10000] User 9919 fut (LSTM multi-input)...
# [9919] Test accuracy: 0.661, Test loss: 2.406
# [9921/10000] User 9920 fut (LSTM multi-input)...
# [9920] Test accuracy: 0.241, Test loss: 4.917
# [9922/10000] User 9921 fut (LSTM multi-input)...
# [9921] Test accuracy: 0.249, Test loss: 3.111
# [9923/10000] User 9922 fut (LSTM multi-input)...
# [9922] Test accuracy: 0.546, Test loss: 2.862
# [9924/10000] User 9923 fut (LSTM multi-input)...
# [9923] Test accuracy: 0.203, Test loss: 4.607
# [9925/10000] User 9924 fut (LSTM multi-input)...
# [9924] Test accuracy: 0.176, Test loss: 4.748
# [9926/10000] User 9925 fut (LSTM multi-input)...
# [9925] Test accuracy: 0.409, Test loss: 2.689
# [9927/10000] User 9926 fut (LSTM multi-input)...
# [9926] Test accuracy: 0.257, Test loss: 4.267
# [9928/10000] User 9927 fut (LSTM multi-input)...
# [9927] Test accuracy: 0.073, Test loss: 5.610
# [9929/10000] User 9928 fut (LSTM multi-input)...
# [9928] Test accuracy: 0.122, Test loss: 5.412
# [9930/10000] User 9929 fut (LSTM multi-input)...
# [9929] Test accuracy: 0.282, Test loss: 2.683
# [9931/10000] User 9930 fut (LSTM multi-input)...
# [9930] Test accuracy: 0.164, Test loss: 5.053
# [9932/10000] User 9931 fut (LSTM multi-input)...
# [9931] Test accuracy: 0.039, Test loss: 5.480
# [9933/10000] User 9932 fut (LSTM multi-input)...
# [9932] Test accuracy: 0.438, Test loss: 2.865
# [9934/10000] User 9933 fut (LSTM multi-input)...
# [9933] Test accuracy: 0.381, Test loss: 2.877
# [9935/10000] User 9934 fut (LSTM multi-input)...
# [9934] Test accuracy: 0.194, Test loss: 3.095
# [9936/10000] User 9935 fut (LSTM multi-input)...
# [9935] Test accuracy: 0.322, Test loss: 2.333
# [9937/10000] User 9936 fut (LSTM multi-input)...
# [9936] Test accuracy: 0.207, Test loss: 4.077
# [9938/10000] User 9937 fut (LSTM multi-input)...
# [9937] Test accuracy: 0.084, Test loss: 5.313
# [9939/10000] User 9938 fut (LSTM multi-input)...
# [9938] Test accuracy: 0.114, Test loss: 6.231
# [9940/10000] User 9939 fut (LSTM multi-input)...
# [9939] Test accuracy: 0.013, Test loss: 6.012
# [9941/10000] User 9940 fut (LSTM multi-input)...
# [9940] Test accuracy: 0.055, Test loss: 6.207
# [9942/10000] User 9941 fut (LSTM multi-input)...
# [9941] Test accuracy: 0.260, Test loss: 3.497
# [9943/10000] User 9942 fut (LSTM multi-input)...
# [9942] Test accuracy: 0.201, Test loss: 4.169
# [9944/10000] User 9943 fut (LSTM multi-input)...
# [9943] Test accuracy: 0.135, Test loss: 4.393
# [9945/10000] User 9944 fut (LSTM multi-input)...
# [9944] Test accuracy: 0.237, Test loss: 4.468
# [9946/10000] User 9945 fut (LSTM multi-input)...
# [9945] Test accuracy: 0.526, Test loss: 2.507
# [9947/10000] User 9946 fut (LSTM multi-input)...
# [9946] Test accuracy: 0.241, Test loss: 4.472
# [9948/10000] User 9947 fut (LSTM multi-input)...
# [9947] Test accuracy: 0.149, Test loss: 4.019
# [9949/10000] User 9948 fut (LSTM multi-input)...
# [9948] Test accuracy: 0.338, Test loss: 3.271
# [9950/10000] User 9949 fut (LSTM multi-input)...
# [9949] Test accuracy: 0.370, Test loss: 3.059
# [9951/10000] User 9950 fut (LSTM multi-input)...
# [9950] Test accuracy: 0.282, Test loss: 3.557
# [9952/10000] User 9951 fut (LSTM multi-input)...
# [9951] Test accuracy: 0.308, Test loss: 4.152
# [9953/10000] User 9952 fut (LSTM multi-input)...
# [9952] Test accuracy: 0.301, Test loss: 3.772
# [9954/10000] User 9953 fut (LSTM multi-input)...
# [9953] Test accuracy: 0.398, Test loss: 3.041
# [9955/10000] User 9954 fut (LSTM multi-input)...
# [9954] Test accuracy: 0.227, Test loss: 4.081
# [9956/10000] User 9955 fut (LSTM multi-input)...
# [9955] Test accuracy: 0.416, Test loss: 4.787
# [9957/10000] User 9956 fut (LSTM multi-input)...
# [9956] Test accuracy: 0.224, Test loss: 3.066
# [9958/10000] User 9957 fut (LSTM multi-input)...
# [9957] Test accuracy: 0.171, Test loss: 4.143
# [9959/10000] User 9958 fut (LSTM multi-input)...
# [9958] Test accuracy: 0.208, Test loss: 4.844
# [9960/10000] User 9959 fut (LSTM multi-input)...
# [9959] Test accuracy: 0.185, Test loss: 5.067
# [9961/10000] User 9960 fut (LSTM multi-input)...
# [9960] Test accuracy: 0.118, Test loss: 6.121
# [9962/10000] User 9961 fut (LSTM multi-input)...
# [9961] Test accuracy: 0.227, Test loss: 3.415
# [9963/10000] User 9962 fut (LSTM multi-input)...
# [9962] Test accuracy: 0.045, Test loss: 6.291
# [9964/10000] User 9963 fut (LSTM multi-input)...
# [9963] Test accuracy: 0.446, Test loss: 1.587
# [9965/10000] User 9964 fut (LSTM multi-input)...
# [9964] Test accuracy: 0.069, Test loss: 5.595
# [9966/10000] User 9965 fut (LSTM multi-input)...
# [9965] Test accuracy: 0.109, Test loss: 5.070
# [9967/10000] User 9966 fut (LSTM multi-input)...
# [9966] Test accuracy: 0.225, Test loss: 4.060
# [9968/10000] User 9967 fut (LSTM multi-input)...
# [9967] Test accuracy: 0.398, Test loss: 2.606
# [9969/10000] User 9968 fut (LSTM multi-input)...
# [9968] Test accuracy: 0.427, Test loss: 1.209
# [9970/10000] User 9969 fut (LSTM multi-input)...
# [9969] Test accuracy: 0.374, Test loss: 3.360
# [9971/10000] User 9970 fut (LSTM multi-input)...
# [9970] Test accuracy: 0.279, Test loss: 3.595
# [9972/10000] User 9971 fut (LSTM multi-input)...
# [9971] Test accuracy: 0.148, Test loss: 4.607
# [9973/10000] User 9972 fut (LSTM multi-input)...
# [9972] Test accuracy: 0.268, Test loss: 3.609
# [9974/10000] User 9973 fut (LSTM multi-input)...
# [9973] Test accuracy: 0.206, Test loss: 4.859
# [9975/10000] User 9974 fut (LSTM multi-input)...
# [9974] Test accuracy: 0.136, Test loss: 4.975
# [9976/10000] User 9975 fut (LSTM multi-input)...
# [9975] Test accuracy: 0.385, Test loss: 2.643
# [9977/10000] User 9976 fut (LSTM multi-input)...
# [9976] Test accuracy: 0.090, Test loss: 5.282
# [9978/10000] User 9977 fut (LSTM multi-input)...
# [9977] Test accuracy: 0.348, Test loss: 3.506
# [9979/10000] User 9978 fut (LSTM multi-input)...
# [9978] Test accuracy: 0.387, Test loss: 2.164
# [9980/10000] User 9979 fut (LSTM multi-input)...
# [9979] Test accuracy: 0.071, Test loss: 5.267
# [9981/10000] User 9980 fut (LSTM multi-input)...
# [9980] Test accuracy: 0.162, Test loss: 4.554
# [9982/10000] User 9981 fut (LSTM multi-input)...
# [9981] Test accuracy: 0.460, Test loss: 2.958
# [9983/10000] User 9982 fut (LSTM multi-input)...
# [9982] Test accuracy: 0.202, Test loss: 4.507
# [9984/10000] User 9983 fut (LSTM multi-input)...
# [9983] Test accuracy: 0.340, Test loss: 2.585
# [9985/10000] User 9984 fut (LSTM multi-input)...
# [9984] Test accuracy: 0.235, Test loss: 3.882
# [9986/10000] User 9985 fut (LSTM multi-input)...
# [9985] Test accuracy: 0.531, Test loss: 2.788
# [9987/10000] User 9986 fut (LSTM multi-input)...
# [9986] Test accuracy: 0.735, Test loss: 1.417
# [9988/10000] User 9987 fut (LSTM multi-input)...
# [9987] Test accuracy: 0.074, Test loss: 5.756
# [9989/10000] User 9988 fut (LSTM multi-input)...
# [9988] Test accuracy: 0.109, Test loss: 4.366
# [9990/10000] User 9989 fut (LSTM multi-input)...
# [9989] Test accuracy: 0.296, Test loss: 2.869
# [9991/10000] User 9990 fut (LSTM multi-input)...
# [9990] Test accuracy: 0.324, Test loss: 3.427
# [9992/10000] User 9991 fut (LSTM multi-input)...
# [9991] Test accuracy: 0.105, Test loss: 5.816
# [9993/10000] User 9992 fut (LSTM multi-input)...
# [9992] Test accuracy: 0.115, Test loss: 5.257
# [9994/10000] User 9993 fut (LSTM multi-input)...
# [9993] Test accuracy: 0.275, Test loss: 3.607
# [9995/10000] User 9994 fut (LSTM multi-input)...
# [9994] Test accuracy: 0.366, Test loss: 4.071
# [9996/10000] User 9995 fut (LSTM multi-input)...
# [9995] Test accuracy: 0.443, Test loss: 2.268
# [9997/10000] User 9996 fut (LSTM multi-input)...
# [9996] Test accuracy: 0.420, Test loss: 2.258
# [9998/10000] User 9997 fut (LSTM multi-input)...
# [9997] Test accuracy: 0.165, Test loss: 3.846
# [9999/10000] User 9998 fut (LSTM multi-input)...
# [9998] Test accuracy: 0.111, Test loss: 4.805
# [10000/10000] User 9999 fut (LSTM multi-input)...
# [9999] Test accuracy: 0.123, Test loss: 4.406
# ✅ Kész! Eredmények a fájlban: results_checkpoint.csv
